# %% [markdown]
# # Lecture 1: Introduction
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/wusche1/cursor-latex-zotero-template/blob/course-template/lectures/01_intro/notebook.ipynb)

# %%
import os
if os.getenv('COLAB_RELEASE_TAG'):
    # !pip install -q some-dependency
    import urllib.request
    urllib.request.urlretrieve(
        "https://raw.githubusercontent.com/wusche1/cursor-latex-zotero-template/course-template/lectures/01_intro/utils.py",
        "utils.py"
    )

from utils import *

# %% [markdown]
# ## Example: Basic Python

# %%
import math

# Quick demo
values = [math.sin(x * 0.1) for x in range(20)]
print(f"Generated {len(values)} values")
print(f"Min: {min(values):.3f}, Max: {max(values):.3f}")

# %%
# Verify we can detect the environment
import sys
print(f"Python {sys.version}")
print(f"Running on Colab: {bool(os.getenv('COLAB_RELEASE_TAG'))}")
